# %% [markdown]
# # NAO Technical Assessment

# %% [markdown]
# ## NAME: Jesubukade Emmanuel Ajakaye
# ### ***ajakaye.bukade@gmail.com     |   (+44)07884489099***

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import dataframe_image as dfi
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error, r2_score

# %% [markdown]
# ### Data Preprocessing
# - Importing Data worksheet
# - Creating end of the year as last day of data aggregation as date
# - setting date as index of table
# - Showing top rows

# %%
def data_wrangling(filename, sheet_name):
    """
    This function completes basic preprocessing on the file and returns
    dataframe ready dataframe for model analysis.
    
    Args:
        filename(str): Name of excel file with extention e.g filename.xlsx
        sheet_name(str): Name of the sheet the dataset is on
    
    Return:
        data(dataframe): This function returns a pandas dataframe
    """

    try:
        data = pd.read_excel(filename, sheet_name) # import file
        date = pd.to_datetime({'year': data["Year"],
                               'month': [12] * len(data["Year"]),
                               'day': [31] * len(data["Year"])},
                               format="%Y") # set as last day of the year
        data.set_index(date, inplace=True) # set date as index

        return data
    
    except Exception as ex:
        return f"The following error occured: {ex}"
    
data = data_wrangling("Dataset.xlsx", "Sheet1")
data.head()
# Out:
#             Year  Agriculture, forestry and fishing  Mining and quarrying  \
# 1990-12-31  1990                            55690.3               50452.8
# 1991-12-31  1991                            55492.6               50608.3
# 1992-12-31  1992                            55149.0               51199.3
# 1993-12-31  1993                            54319.9               50807.1
# 1994-12-31  1994                            55129.7               44588.4
#
#             Manufacturing  \
# 1990-12-31       175212.7
# 1991-12-31       176254.4
# 1992-12-31       169388.2
# 1993-12-31       164365.0
# 1994-12-31       167285.9
#
#             Electricity, gas, steam and air conditioning supply  \
# 1990-12-31                                           217602.2
# 1991-12-31                                           214317.5
# 1992-12-31                                           202469.2
# 1993-12-31                                           184997.2
# 1994-12-31                                           180721.6
#
#             Water supply; sewerage, waste management and remediation activities  \
# 1990-12-31                                            75316.3
# 1991-12-31                                            76852.7
# 1992-12-31                                            76959.1
# 1993-12-31                                            77275.6
# 1994-12-31                                            77637.9
#
#             Construction  \
# 1990-12-31        8201.2
# 1991-12-31        8072.0
# 1992-12-31        8188.3
# 1993-12-31        8275.1
# 1994-12-31        8633.8
#
#             Wholesale and retail trade; repair of motor vehicles and motorcycles  \
# 1990-12-31                                            11560.8
# 1991-12-31                                            11984.1
# 1992-12-31                                            11789.9
# 1993-12-31                                            12032.9
# 1994-12-31                                            12403.1
#
#             Transport and storage  Accommodation and food services  ...  \
# 1990-12-31                66985.3                           3015.3  ...
# 1991-12-31                67438.6                           3453.5  ...
# 1992-12-31                68438.5                           3163.4  ...
# 1993-12-31                69735.2                           3371.4  ...
# 1994-12-31                70659.2                           3342.3  ...
#
#             Public administration and defence; compulsory social security  \
# 1990-12-31                                            12058.4
# 1991-12-31                                            11381.2
# 1992-12-31                                            11523.4
# 1993-12-31                                            11710.9
# 1994-12-31                                            11071.3
#
#             Education  Human health and social work activities  \
# 1990-12-31     6421.4                                   6059.8
# 1991-12-31     6740.7                                   6386.3
# 1992-12-31     6867.6                                   6746.9
# 1993-12-31     5966.1                                   6431.4
# 1994-12-31     5438.4                                   6517.7
#
#             Arts, entertainment and recreation  Other service activities  \
# 1990-12-31                              1717.0                     966.0
# 1991-12-31                              1816.6                    1014.1
# 1992-12-31                              1640.3                     970.7
# 1993-12-31                              1721.5                    1013.0
# 1994-12-31                              1664.2                    1004.7
#
#             Activities of households as employers  \
# 1990-12-31                                  100.9
# 1991-12-31                                   83.3
# 1992-12-31                                   83.5
# 1993-12-31                                   84.5
# 1994-12-31                                   88.4
#
#             Consumer expenditure [note 4]  Consumer expenditure - Not travel  \
# 1990-12-31                       143742.1                            83111.6
# 1991-12-31                       152223.6                            91987.3
# 1992-12-31                       150566.9                            89330.2
# 1993-12-31                       155345.9                            93635.0
# 1994-12-31                       150151.8                            89243.6
#
#             Consumer expenditure - Travel  Total greenhouse gas emissions
# 1990-12-31                        60630.4                        842320.1
# 1991-12-31                        60236.3                        851881.6
# 1992-12-31                        61236.7                        832675.6
# 1993-12-31                        61710.9                        815077.2
# 1994-12-31                        60908.2                        804149.2
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Explorative Data Analysis

# %%
data_col = data.columns[data.columns != "Year"]
fig, ax = plt.subplots(figsize=(8,6))

ax.plot(data.index, data[data_col])

ax.set_title("Greenhouse Gas Emissions Trends in UK")
ax.set_xlabel("Year")
ax.set_ylabel("Mass of air emissions per annum in thousand tonnes")

plt.show()

for col in data_col:
    fig, ax = plt.subplots(figsize=(6,4))

    ax.plot(data.index, data[col])

    ax.set_title(f"Trends of Total Greenhouse Gas Emissions in {col} industry")
    ax.set_xlabel("Year")
    ax.set_ylabel("Mass of air emissions per annum in thousand tonnes")

    plt.show()

# %% [markdown]
# ## Investigating Change in greenhouse gas (GHG) over Time
# ### Model Building: Kendall Tau Statistics

# %%
def tau_model(data):
    """
    This function performs the Kendall Tau Statistics on dataset.

    Args:
        data(dataframe): imported dataset for model analysis

    Return:
        tau_result_df(dataframe): pandas dataframe of model values (tau, pvalue)
    """
    try:
        tau_result = {}
        data_col = data.columns[data.columns != "Year"] # Getting the column names in the dataset except year

        X = data["Year"].values.reshape(-1, 1) # Extract the time series values and reshape them
        for col in data_col:
            y = data[col].values.reshape(-1, 1) # Extract the variable values and reshape

            tau, pvalue = stats.kendalltau(X, y) # Initializing and Fitting Kendall Tau to the data

            tau_result[col] = (tau, pvalue) # Appending variable and model value to dictionary
            tau_result_df = pd.DataFrame(tau_result, index=["tau", "pvalue"]).T # Converting Dictionary to Dataframe

        return(tau_result_df)
    
    except Exception as ex:
        return f"The following error occured: {ex}"

# %% [markdown]
# #### Visualising Kendall Tau Result on Table
# ***Colours adding to be more informative***

# %%
tau_model_result = tau_model(data)

alpha = 0.01 # Threshold set to check if a signifant trend exist in series at 99%

def colour_significant(value):
    """Function to check and add background colour based on threshold.

    Args:
        value: subset(column) which checks will be performed on
    
    Return:
        background colour for value
    """
    if value < alpha:
        color = 'green'
    else:
        color = 'red'
    return 'background-color: %s' % color

# Displaying Kendall Tau Model Dataframe
tau_model_result_styled = tau_model_result.style.map(colour_significant, subset='pvalue')\
    .bar(subset = 'tau', align='mid', color=['green', 'red'])

tau_model_result_styled.export_png('tau_model_result_styled.png') # Save table to image
tau_model_result_styled
# Out:
# <style type="text/css">
# #T_6ab5b_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 17.3%, green 17.3%, green 58.9%, transparent 58.9%);
# }
# #T_6ab5b_row0_col1, #T_6ab5b_row1_col1, #T_6ab5b_row2_col1, #T_6ab5b_row3_col1, #T_6ab5b_row4_col1, #T_6ab5b_row5_col1, #T_6ab5b_row6_col1, #T_6ab5b_row8_col1, #T_6ab5b_row9_col1, #T_6ab5b_row10_col1, #T_6ab5b_row11_col1, #T_6ab5b_row12_col1, #T_6ab5b_row14_col1, #T_6ab5b_row15_col1, #T_6ab5b_row17_col1, #T_6ab5b_row18_col1, #T_6ab5b_row20_col1, #T_6ab5b_row21_col1, #T_6ab5b_row23_col1 {
#   background-color: green;
# }
# #T_6ab5b_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 2.2%, green 2.2%, green 58.9%, transparent 58.9%);
# }
# #T_6ab5b_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 58.9%, transparent 58.9%);
# }
# #T_6ab5b_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 21.3%, green 21.3%, green 58.9%, transparent 58.9%);
# }
# #T_6ab5b_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 6.0%, green 6.0%, green 58.9%, transparent 58.9%);
# }
# #T_6ab5b_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 58.9%, red 58.9%, red 99.6%, transparent 99.6%);
# }
# #T_6ab5b_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 58.9%, red 58.9%, red 87.1%, transparent 87.1%);
# }
# #T_6ab5b_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 58.5%, green 58.5%, green 58.9%, transparent 58.9%);
# }
# #T_6ab5b_row7_col1, #T_6ab5b_row13_col1, #T_6ab5b_row16_col1, #T_6ab5b_row19_col1, #T_6ab5b_row22_col1 {
#   background-color: red;
# }
# #T_6ab5b_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 58.9%, red 58.9%, red 92.9%, transparent 92.9%);
# }
# #T_6ab5b_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 15.1%, green 15.1%, green 58.9%, transparent 58.9%);
# }
# #T_6ab5b_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 25.1%, green 25.1%, green 58.9%, transparent 58.9%);
# }
# #T_6ab5b_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 58.9%, red 58.9%, red 100.0%, transparent 100.0%);
# }
# #T_6ab5b_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 10.2%, green 10.2%, green 58.9%, transparent 58.9%);
# }
# #T_6ab5b_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 58.9%, red 58.9%, red 78.0%, transparent 78.0%);
# }
# #T_6ab5b_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 0.7%, green 0.7%, green 58.9%, transparent 58.9%);
# }
# #T_6ab5b_row15_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 8.5%, green 8.5%, green 58.9%, transparent 58.9%);
# }
# #T_6ab5b_row16_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 55.2%, green 55.2%, green 58.9%, transparent 58.9%);
# }
# #T_6ab5b_row17_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 25.9%, green 25.9%, green 58.9%, transparent 58.9%);
# }
# #T_6ab5b_row18_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 34.6%, green 34.6%, green 58.9%, transparent 58.9%);
# }
# #T_6ab5b_row19_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 58.9%, red 58.9%, red 70.0%, transparent 70.0%);
# }
# #T_6ab5b_row20_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 32.2%, green 32.2%, green 58.9%, transparent 58.9%);
# }
# #T_6ab5b_row21_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 22.0%, green 22.0%, green 58.9%, transparent 58.9%);
# }
# #T_6ab5b_row22_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 58.9%, red 58.9%, red 75.6%, transparent 75.6%);
# }
# #T_6ab5b_row23_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 1.3%, green 1.3%, green 58.9%, transparent 58.9%);
# }
# </style>
# <table id="T_6ab5b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6ab5b_level0_col0" class="col_heading level0 col0" >tau</th>
#       <th id="T_6ab5b_level0_col1" class="col_heading level0 col1" >pvalue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ab5b_level0_row0" class="row_heading level0 row0" >Agriculture, forestry and fishing</th>
#       <td id="T_6ab5b_row0_col0" class="data row0 col0" >-0.668449</td>
#       <td id="T_6ab5b_row0_col1" class="data row0 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6ab5b_level0_row1" class="row_heading level0 row1" >Mining and quarrying</th>
#       <td id="T_6ab5b_row1_col0" class="data row1 col0" >-0.910873</td>
#       <td id="T_6ab5b_row1_col1" class="data row1 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6ab5b_level0_row2" class="row_heading level0 row2" >Manufacturing</th>
#       <td id="T_6ab5b_row2_col0" class="data row2 col0" >-0.946524</td>
#       <td id="T_6ab5b_row2_col1" class="data row2 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6ab5b_level0_row3" class="row_heading level0 row3" >Electricity, gas, steam and air conditioning supply</th>
#       <td id="T_6ab5b_row3_col0" class="data row3 col0" >-0.604278</td>
#       <td id="T_6ab5b_row3_col1" class="data row3 col1" >0.000001</td>
#     </tr>
#     <tr>
#       <th id="T_6ab5b_level0_row4" class="row_heading level0 row4" >Water supply; sewerage, waste management and remediation activities</th>
#       <td id="T_6ab5b_row4_col0" class="data row4 col0" >-0.850267</td>
#       <td id="T_6ab5b_row4_col1" class="data row4 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6ab5b_level0_row5" class="row_heading level0 row5" >Construction</th>
#       <td id="T_6ab5b_row5_col0" class="data row5 col0" >0.654189</td>
#       <td id="T_6ab5b_row5_col1" class="data row5 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6ab5b_level0_row6" class="row_heading level0 row6" >Wholesale and retail trade; repair of motor vehicles and motorcycles</th>
#       <td id="T_6ab5b_row6_col0" class="data row6 col0" >0.454545</td>
#       <td id="T_6ab5b_row6_col1" class="data row6 col1" >0.000157</td>
#     </tr>
#     <tr>
#       <th id="T_6ab5b_level0_row7" class="row_heading level0 row7" >Transport and storage</th>
#       <td id="T_6ab5b_row7_col0" class="data row7 col0" >-0.005348</td>
#       <td id="T_6ab5b_row7_col1" class="data row7 col1" >0.964527</td>
#     </tr>
#     <tr>
#       <th id="T_6ab5b_level0_row8" class="row_heading level0 row8" >Accommodation and food services</th>
#       <td id="T_6ab5b_row8_col0" class="data row8 col0" >0.547237</td>
#       <td id="T_6ab5b_row8_col1" class="data row8 col1" >0.000005</td>
#     </tr>
#     <tr>
#       <th id="T_6ab5b_level0_row9" class="row_heading level0 row9" >Information and communication</th>
#       <td id="T_6ab5b_row9_col0" class="data row9 col0" >-0.704100</td>
#       <td id="T_6ab5b_row9_col1" class="data row9 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6ab5b_level0_row10" class="row_heading level0 row10" >Financial and insurance activities</th>
#       <td id="T_6ab5b_row10_col0" class="data row10 col0" >-0.542373</td>
#       <td id="T_6ab5b_row10_col1" class="data row10 col1" >0.000007</td>
#     </tr>
#     <tr>
#       <th id="T_6ab5b_level0_row11" class="row_heading level0 row11" >Real estate activities</th>
#       <td id="T_6ab5b_row11_col0" class="data row11 col0" >0.661319</td>
#       <td id="T_6ab5b_row11_col1" class="data row11 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6ab5b_level0_row12" class="row_heading level0 row12" >Professional, scientific and technical activities</th>
#       <td id="T_6ab5b_row12_col0" class="data row12 col0" >-0.782531</td>
#       <td id="T_6ab5b_row12_col1" class="data row12 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6ab5b_level0_row13" class="row_heading level0 row13" >Administrative and support service activities</th>
#       <td id="T_6ab5b_row13_col0" class="data row13 col0" >0.308378</td>
#       <td id="T_6ab5b_row13_col1" class="data row13 col1" >0.010329</td>
#     </tr>
#     <tr>
#       <th

# %% [markdown]
# ### Further Investigation and Forcasting: Linear Regression Model

# %%
def linear_reg_model(data):
    """
    This function performs Linear regression on columns of the dataset
    and forcasts the next five years

    Args:
        data(dataframe): imported dataset for model analysis

    Return:
        lrm_result_df(dataframe): pandas dataframe of model metrics
        data_forcast_df(dataframe): values of the forcasted five years
        plot_data(dictionary): All model predicted values for linear line ploting
    """
    try:
        result = {}
        data_forcast = {"Year": [year for year in range((data["Year"].iloc[-1] + 1), (data["Year"].iloc[-1] + 6))]} # Get forcasting years
        plot_data = {"Date": data.index}

        data_col = data.columns[data.columns != "Year"] # Getting the column names in the dataset except year

        # Extract the time series values and reshape them
        X = data["Year"].values.reshape(-1, 1)
        X_forcast = np.array(data_forcast["Year"]).reshape(-1, 1)

        for col in data_col:
            y = data[col].values # Extract the variable values and reshape

            model = LinearRegression().fit(X, y)    # Initializing and Fitting a linear regression model to the data
            y_pred = model.predict(X)               # Linear Model Predictions

            # Getting Metrics of The Linear Model
            mean = np.mean(y)                                   # Calculating the Mean Value of Variable
            slope = model.coef_[0]                              # Extracting Slope of Model
            intercept = model.intercept_                        # Extracting Intercept of Model
            mape = mean_absolute_percentage_error(y, y_pred)    # Calculating Mean Absolute Percentage Error
            r2 = r2_score(y,y_pred)                             # Calculating R2 score of Model
            mae = mean_absolute_error(y, y_pred)                # Calculating Mean Absolute Error
            mse = mean_squared_error(y, y_pred)                 # Calculating Mean Squared Error
            rmse = np.sqrt(mse)                                 # Calculating Root Mean Squared Error

            # Appending to Dictionary and converting Predictions to Dataframe
            result[col] = (mean, mape, r2, slope, intercept, mae, mse, rmse)
            lrm_result_df = pd.DataFrame(result, index=["mean", "mape", "r2_score", "gradient", "intercept", "mae", "mse", "rmse"]).T

            
            ##### Forcasting Values for next five Years
            forcasting = model.predict(X_forcast)

            # Appending to Dictionary and converting Forcast to Dataframe
            data_forcast[col] = forcasting.tolist()
            data_forcast_df = pd.DataFrame(data_forcast)
            date = pd.to_datetime({'year': data_forcast["Year"],
                                'month': [12] * len(data_forcast["Year"]),
                                'day': [31] * len(data_forcast["Year"])},
                                format="%Y")
            data_forcast_df.set_index(date, inplace=True)

            # Preparing Predicted and Forcasted Data for plotting
            plot_data[col] = {}
            plot_data[col] = np.concatenate((y_pred, forcasting), axis=None)
            

        plot_data["Date"] = np.concatenate((plot_data["Date"], data_forcast_df.index), axis=None) 

        return (lrm_result_df, data_forcast_df, plot_data)

    except Exception as ex:
        return f"The following error occured: {ex}"

# %%
# Calling function
lrm_result_df, data_forcast_df, plot_data = linear_reg_model(data)

# %%
data_forcast_df[["Total greenhouse gas emissions"]].dfi.export('GHG_forcast.png')
data_forcast_df[["Total greenhouse gas emissions"]]
# Out:
#             Total greenhouse gas emissions
# 2024-12-31                   499563.249733
# 2025-12-31                   488090.440474
# 2026-12-31                   476617.631215
# 2027-12-31                   465144.821956
# 2028-12-31                   453672.012697

# %% [markdown]
# #### Visualising Linear Regression Model Result on Table
# ***Colours adding to be more informative***

# %%
# Visualizing the output
lrm_result_df_styled = lrm_result_df.style.format({'mean': '{:,.2f}', 'gradient': '{:,.2f}', 'intercept': '{:,.2f}',
                                                   'mae': '{:,.2f}', 'mse': '{:,.2f}', 'rmse': '{:,.2f}'})\
                                                    .bar(subset = 'r2_score', align='left', color=['red', 'green'])\
                                                    .bar(subset = 'mape', align='right', color=['red', 'green'])\
                                                    .bar(subset = ['gradient','intercept'], align='mid', color=['red', 'green'])

lrm_result_df_styled.export_png('lrm_result_df_styled.png') # Save table to image
lrm_result_df_styled
# Out:
# <style type="text/css">
# #T_a4cce_row0_col1, #T_a4cce_row14_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 100.0%, transparent 100.0%);
# }
# #T_a4cce_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 76.7%, transparent 76.7%);
# }
# #T_a4cce_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 97.5%, red 97.5%, red 99.2%, transparent 99.2%);
# }
# #T_a4cce_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 0.7%, green 0.7%, green 2.6%, transparent 2.6%);
# }
# #T_a4cce_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 47.2%, green 47.2%, green 100.0%, transparent 100.0%);
# }
# #T_a4cce_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 98.1%, transparent 98.1%);
# }
# #T_a4cce_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 89.5%, red 89.5%, red 99.2%, transparent 99.2%);
# }
# #T_a4cce_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 0.7%, green 0.7%, green 10.2%, transparent 10.2%);
# }
# #T_a4cce_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 33.0%, green 33.0%, green 100.0%, transparent 100.0%);
# }
# #T_a4cce_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 97.9%, transparent 97.9%);
# }
# #T_a4cce_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 69.1%, red 69.1%, red 99.2%, transparent 99.2%);
# }
# #T_a4cce_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 0.7%, green 0.7%, green 30.4%, transparent 30.4%);
# }
# #T_a4cce_row3_col1, #T_a4cce_row7_col2 {
#   width: 10em;
# }
# #T_a4cce_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 70.7%, transparent 70.7%);
# }
# #T_a4cce_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 68.3%, red 68.3%, red 99.2%, transparent 99.2%);
# }
# #T_a4cce_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 0.7%, green 0.7%, green 31.4%, transparent 31.4%);
# }
# #T_a4cce_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 83.2%, green 83.2%, green 100.0%, transparent 100.0%);
# }
# #T_a4cce_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 95.3%, transparent 95.3%);
# }
# #T_a4cce_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 80.8%, red 80.8%, red 99.2%, transparent 99.2%);
# }
# #T_a4cce_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 0.7%, green 0.7%, green 18.8%, transparent 18.8%);
# }
# #T_a4cce_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 19.3%, green 19.3%, green 100.0%, transparent 100.0%);
# }
# #T_a4cce_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 67.9%, transparent 67.9%);
# }
# #T_a4cce_row5_col3, #T_a4cce_row22_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 99.2%, green 99.2%, green 99.8%, transparent 99.8%);
# }
# #T_a4cce_row5_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 0.1%, red 0.1%, red 0.7%, transparent 0.7%);
# }
# #T_a4cce_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 45.2%, green 45.2%, green 100.0%, transparent 100.0%);
# }
# #T_a4cce_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 29.4%, transparent 29.4%);
# }
# #T_a4cce_row6_col3, #T_a4cce_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 99.2%, green 99.2%, green 100.0%, transparent 100.0%);
# }
# #T_a4cce_row6_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, red 0.7%, transparent 0.7%);
# }
# #T_a4cce_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 67.9%, green 67.9%, green 100.0%, transparent 100.0%);
# }
# #T_a4cce_row7_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 0.3%, red 0.3%, red 0.7%, transparent 0.7%);
# }
# #T_a4cce_row8_col1, #T_a4cce_row14_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 32.1%, green 32.1%, green 100.0%, transparent 100.0%);
# }
# #T_a4cce_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 61.3%, transparent 61.3%);
# }
# #T_a4cce_row8_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 99.2%, green 99.2%, green 99.5%, transparent 99.5%);
# }
# #T_a4cce_row8_col4, #T_a4cce_row22_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 0.4%, red 0.4%, red 0.7%, transparent 0.7%);
# }
# #T_a4cce_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 30.4%, green 30.4%, green 100.0%, transparent 100.0%);
# }
# #T_a4cce_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 80.2%, transparent 80.2%);
# }
# #T_a4cce_row9_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 99.1%, red 99.1%, red 99.2%, transparent 99.2%);
# }
# #T_a4cce_row9_col4, #T_a4cce_row16_col4, #T_a4cce_row18_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 0.7%, green 0.7%, green 0.8%, transparent 0.8%);
# }
# #T_a4cce_row10_col1, #T_a4cce_row13_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 15.6%, green 15.6%, green 100.0%, transparent 100.0%);
# }
# #T_a4cce_row10_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 50.3%, transparent 50.3%);
# }
# #T_a4cce_row10_col3, #T_a4cce_row16_col3, #T_a4cce_row18_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 99.2%, red 99.2%, red 99.2%, transparent 99.2%);
# }
# #T_a4cce_row10_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 0.7%, green 0.7%, green 0.7%, transparent 0.7%);
# }
# #T_a4cce_row11_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 23.3%, green 23.3%, green 100.0%, transparent 100.0%);
# }
# #T_a4cce_row11_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 73.9%, transparent 73.9%);
# }
# #T_a4cce_row11_col3, #T_a4cce_row13_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 99.2%, green 99.2%, green 99.3%, transparent 99.3%);
# }
# #T_a4cce_row11_col4, #T_a4cce_row13_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 0.6%, red 0.6%, red 0.7%, transparent 0.7%);
# }
# #T_a4cce_row12_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 18.8%, green 18.8%, green 100.0%, transparent 100.0%);
# }
# #T_a4cce_row12_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 91.8%, transparent 91.8%);
# }
# #T_a4cce_row12_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 98.9%, red 98.9%, red 99.2%, transparent 99.2%);
# }
# #T_a4cce_row12_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 0.7%, green 0.7%, green 1.0%, transparent 1.0%);
# }
# #T_a4cce_row13_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 22.5%, transparent 22.5%);
# }
# #T_a4cce_row14_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 96.9%, red 96.9%, red 99.2%, transparent 99.2%);
# }
# #T_a4cce_row14_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 0.7%, green 0.7%, green 3.0%, transparent 3.0%);
# }
# #T_a4cce_row15_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 54.9%, green 54.9%, green 100.0%, transparent 100.0%);
# }
# #T_a4cce_row15_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 91.7%, transparent 91.7%);
# }
# #T_a4cce_row15_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 98.1%, red 98.1%, red 99.2%, transparent 99.2%);
# }
# #T_a4cce_row15_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 0.7%, green 0.7%, green 1.8%, transparent 1.8%);
# }
# #T_a4cce_row16_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 51.6%, green 51.6%, green 100.0%, transparent 100.0%);
# }
# #T_a4cce_row16_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 0.4%, transparent 0.4%);
# }
# #T_a4cce_row17_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 71.6%, green 71.6%, green 100.0%, transparent 100.0%);
# }
# #T_a4cc

# %%
# Ploting Actual values and predicted values of Total Greenhouse Gas Emissions Trends
fig, ax = plt.subplots(figsize=(12,8))

ax.plot(data.index, data['Total greenhouse gas emissions'], label="Actual Value")
ax.plot(plot_data["Date"], plot_data['Total greenhouse gas emissions'], label="Linear Model Prediction")

ax.set_title("Actual values and predicted values of Total Greenhouse Gas Emissions Trends")
ax.set_xlabel("Year")
ax.set_ylabel("Mass of air emissions per annum in thousand tonnes")
ax.legend()

fig.savefig("GHG_emissions.png")
plt.show()
